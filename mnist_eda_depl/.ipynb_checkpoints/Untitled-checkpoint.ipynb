# %%
import boto3
s3 = boto3.client("s3", region_name='ap-south-1')
s3.download_file("kubeflow-ds-test-raw-lake", "data/train.csv", "data/train.csv")

# %%
import pandas as pd
df_train = df = pd.read_csv('data/train.csv', sep=',', header=0)

x = df_train.iloc[:, 1:]
y = df_train['label'].tolist()

# # Select 10000 rows data as a testing dataset
x_test = x.iloc[0:10000, :].values.astype('float32') # all pixel values 
y_test = y[0:10000] # Select label for testing data
x_train = x.iloc[10000:, :].values.astype('float32') # all pixel values 
y_train = y[10000:]

pd.DataFrame(x_train).to_csv('training_data.csv', index=False)
pd.DataFrame(y_train).to_csv('training_labels.csv', index=False)

pd.DataFrame(x_test).to_csv('test_data.csv', index=False, headers=False)
pd.DataFrame(y_test).to_csv('test_labels.csv', index=False, headers=False)
print("ALL DONE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-79da03ae1b0b> in <module>
#      14 pd.DataFrame(y_train).to_csv('training_labels.csv', index=False)
#      15
# ---> 16 pd.DataFrame(x_test).to_csv('test_data.csv', index=False, headers=False)
#      17 pd.DataFrame(y_test).to_csv('test_labels.csv', index=False, headers=False)
#      18 print("ALL DONE")
#
# TypeError: to_csv() got an unexpected keyword argument 'headers'

# %%
import pandas as pd
    
x_train = pd.read_csv('training_data.csv')
x_test = pd.read_csv('test_data.csv')

x_train = x_train/255.0
x_test = x_test/255.0

x_train.to_csv('normalized_train_data.csv', index=False)
x_test.to_csv('normalized_test_data.csv', index=False)

print("ALL DONE")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

depth = 2
n_estimators = 50
random_state = 0


x_train = pd.read_csv('normalized_train_data.csv')
y_train = pd.read_csv('training_labels.csv')


y_test = pd.read_csv('normalized_test_data.csv')
y_train = pd.read_csv('test_labels.csv')

print("heere", 1)
model_clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=depth, random_state=random_state)
print("here", 2)
# Train the Random Forest algorithm
model_clf.fit(x_train, y_train)
print("here", 3)
# validate
y_pred = model_clf.predict(x_test)
print("here", 4)
# calculate accuracy
total = len(y_pred)
wrong = 0
for pred, truth in zip(y_pred, y_test):
    wrong += 1 if pred != truth else 0
print("here", 5)
accuracy = ((total - wrong)/total) * 100.0

########## log model ####################
import mlflow

mlflow.set_tracking_uri(mlflow_tracking_uri)
mlflow.set_experiment(mlflow_experiment_name)

with mlflow.start_run() as run:
    mlflow.log_param("n_estimators", n_estimators)
    mlflow.log_param("max_depth", depth)
    mlflow.log_param("random_state", random_state)
    mlflow.log_metric("accuracy", accuracy)

    mlflow.sklearn.log_model(model_clf, "model", registered_model_name=model_name)

    model_artifact_location = run.info.artifact_uri + "/model"
    logged_model = 'runs:/'+run.info.run_id+'/model'

print(accuracy, logged_model)

# %%
y_train = pd.read_csv('training_labels.csv')
print(y_train)
# Out:
#        0
# 0      2
# 1      5
# 2      9
# 3      9
# 4      3
# 5      6
# 6      1
# 7      0
# 8      5
# 9      1
# 10     0
# 11     2
# 12     5
# 13     5
# 14     5
# 15     7
# 16     3
# 17     0
# 18     3
# 19     7
# 20     4
# 21     6
# 22     1
# 23     4
# 24     8
# 25     1
# 26     4
# 27     2
# 28     7
# 29     3
# ...   ..
# 31970  2
# 31971  3
# 31972  4
# 31973  4
# 31974  3
# 31975  9
# 31976  2
# 31977  4
# 31978  4
# 31979  4
# 31980  7
# 31981  2
# 31982  8
# 31983  7
# 31984  3
# 31985  3
# 31986  0
# 31987  5
# 31988  0
# 31989  5
# 31990  3
# 31991  1
# 31992  9
# 31993  6
# 31994  4
# 31995  0
# 31996  1
# 31997  7
# 31998  6
# 31999  9
#
# [32000 rows x 1 columns]
